# %%
import pandas as pd

df = pd.read_csv('../resource/jobs_3years.csv')

# %%
df['jobId'].value_counts()
# Out:
# jobId
# KJKQ001812310002    1
# K140022008240025    1
# KJKJ002008240012    1
# K171112008240077    1
# K140022008240024    1
#                    ..
# KJKN001804170013    1
# K171111804170075    1
# KJKN001804170012    1
# K150011804170124    1
# K152122201030037    1
# Name: count, Length: 84634, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84634 entries, 0 to 84633
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   84634 non-null  int64
#  1   acptMthd     84634 non-null  object
#  2   deadline     84634 non-null  object
#  3   emplymShp    84634 non-null  object
#  4   emplymShpNm  84634 non-null  object
#  5   frDd         84634 non-null  int64
#  6   jobId        84634 non-null  object
#  7   jobcls       4329 non-null   object
#  8   jobclsNm     4321 non-null   object
#  9   oranNm       84634 non-null  object
#  10  organYn      84634 non-null  object
#  11  recrtTitle   84634 non-null  object
#  12  stmId        84634 non-null  object
#  13  stmNm        84634 non-null  object
#  14  toDd         84634 non-null  int64
#  15  workPlc      84634 non-null  float64
#  16  workPlcNm    0 non-null      float64
# dtypes: float64(2), int64(3), object(12)
# memory usage: 11.0+ MB

# %%
import matplotlib.pyplot as plt
df['workPlc'].hist()
plt.show()

# %%
# 근무지코드 분포
counts = df['workPlc'].value_counts()
percentage = df['workPlc'].value_counts(normalize=True) * 100

pd.concat([counts, percentage], axis=1)
# Out:
#           count  proportion
# workPlc
# 110040.0   3515    4.153177
# 30240.0    2548    3.010610
# 30200.0    2486    2.937354
# 30530.0    2452    2.897181
# 30140.0    2254    2.663232
# ...         ...         ...
# 120140.0      2    0.002363
# 20170.0       1    0.001182
# 170010.0      1    0.001182
# 130130.0      1    0.001182
# 120020.0      1    0.001182
#
# [237 rows x 2 columns]

# %%
# 시작접수일 데이터 분포
import matplotlib.pyplot as plt
df['frDd'].hist()
plt.show()

# %%
# 년월 데이터 분포
df['year_month'] = df['frDd'].astype(str).str[:6]
df.groupby(['year_month']).size()
# Out:
# year_month
# 201801    3625
# 201802    3179
# 201803    3878
# 201804    3504
# 201805    3519
# 201806    3226
# 201807    3628
# 201808    3570
# 201809    2660
# 201810    3424
# 201811    3108
# 201812    3497
# 202001    2640
# 202002    2849
# 202003    2459
# 202004    2002
# 202005    2600
# 202006    3261
# 202007    3397
# 202008    3547
# 202009    2909
# 202010    3582
# 202011    3754
# 202012    4254
# 202201     498
# 202202     515
# 202203     551
# 202204     562
# 202205     586
# 202206     592
# 202207     568
# 202208     527
# 202209     548
# 202210     495
# 202211     506
# 202212     614
# dtype: int64

# %%
# 이상치 데이터 확인
df[df['frDd'] > df['toDd']]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, acptMthd, deadline, emplymShp, emplymShpNm, frDd, jobId, jobcls, jobclsNm, oranNm, organYn, recrtTitle, stmId, stmNm, toDd, workPlc, workPlcNm, year_month]
# Index: []
